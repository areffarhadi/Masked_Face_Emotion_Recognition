# %% [markdown]
# # Convert Face Image Dataset to Masked face
#
# in this script we masked JAFFE dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
! ls
# Out:
# Mounted at /content/drive
# drive  sample_data

# %%
# %cd /content/drive
! ls
# Out:
# /content/drive
# MyDrive

# %%
# %cd MyDrive

! ls
# Out:
# /content/drive/MyDrive
# 'Colab Notebooks'   Colab_Notebooks  'To-do list.gsheet'

# %%
# %cd Colab_Notebooks 
! ls
# Out:
# /content/drive/MyDrive/Colab_Notebooks
# jaffe			MaskTheFace		MTCNN_OUTPUT_surge_crop
# jaffe_jpg		MaskTheFace2		MY_FaceMask.ipynb
# jaffe_jpg_masked	MTCNN_OUTPUT		output
# jaffe_jpg_masked_cloth	MTCNN_OUTPUT_all	output2
# jaffe_jpg_masked_KN95	MTCNN_OUTPUT_KN95_crop	Untitled1.ipynb
# jaffe_jpg_masked_N95	MTCNN_OUTPUT_N95_crop
# jaffe_jpg_masked_surge	MTCNN_OUTPUT_surge

# %%
import numpy
! git clone https://github.com/aqeelanwar/MaskTheFace.git
# Out:
# fatal: destination path 'MaskTheFace' already exists and is not an empty directory.

# %%
# %cd MaskTheFace
# Out:
# /content/drive/MyDrive/Colab_Notebooks/MaskTheFace

# %%
! pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached certifi-2020.4.5.1-py2.py3-none-any.whl (157 kB)
# ...
#   Using cached dlib-19.19.0.tar.gz (3.2 MB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached dotmap-1.3.14-py3-none-any.whl (10 kB)
# ...
#   Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# ...
#   Using cached face_recognition_models-0.3.0.tar.gz (100.1 MB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached numpy-1.18.4-cp38-cp38-manylinux1_x86_64.whl (20.7 MB)
# ...
#   Using cached opencv_python-4.2.0.34-cp38-cp38-manylinux1_x86_64.whl (28.2 MB)
# ...
#   Using cached tqdm-4.46.0-py2.py3-none-any.whl (63 kB)
# ...
#   Using cached wincertstore-0.2-py2.py3-none-any.whl (8.8 kB)
# ...
#   Using cached imutils-0.5.3.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached requests-2.24.0-py2.py3-none-any.whl (61 kB)
# ...
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# ...

# %%
# !python mask_the_face.py --path '/content/drive/MyDrive/Colab_Notebooks/jaffe_jpg' --mask_type 'cloth' --verbose --write_original_image
# Out:
#  __  __           _ _______ _          ______
# |  \/  |         | |__   __| |        |  ____|
# | \  / | __ _ ___| | _| |  | |__   ___| |__ __ _  ___ ___
# | |\/| |/ _` / __| |/ / |  | '_ \ / _ \  __/ _` |/ __/ _ \
# | |  | | (_| \__ \   <| |  | | | |  __/ | | (_| | (_|  __/
# |_|  |_|\__,_|___/_|\_\_|  |_| |_|\___|_|  \__,_|\___\___|
# -------------------------------------------------------------
# -------------------- Masking image files --------------------
# -------------------------------------------------------------
# Processing: /content/drive/MyDrive/Colab_Notebooks/jaffe_jpg/YM_FE2_68.jpg
# Faces found:  1
# Processing: /content/drive/MyDrive/Colab_Notebooks/jaffe_jpg/YM_FE3_69.jpg
# Faces found:  1
# Processing: /content/drive/MyDrive/Colab_Notebooks/jaffe_jpg/YM_FE4_70.jpg
# Faces found:  1
# Processing: /content/drive/MyDrive/Colab_Notebooks/jaffe_jpg/YM_HA1_52.jpg
# Faces found:  1
# Processing: /content/drive/MyDrive/Colab_Notebooks/jaffe_jpg/YM_HA2_53.jpg
# ...
